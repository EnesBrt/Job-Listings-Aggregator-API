# %%
import json
import pandas as pd

# %%
with open('jobs.json', 'r') as infile:
    json_data = json.load(infile)

# %%
df = pd.json_normalize(json_data)

# %%
df['Job Title'] = df['Job Title'].str.replace('CDI', '', case=False).str.strip()
df['Job Title'] = df['Job Title'].str.replace('cdi', '', case=False).str.strip()
df
# Out:
#                                             Job Title  \
# 0                  Software Engineer (Python / React)
# 1   Développeur backend senior  - Nantes (Java/Pyt...
# 2              Developer Fullstack Python/react- Lyon
# 3                       Développeur/se Backend Python
# 4               Développeur/se Fullstack Python/React
# 5   Ingénieur de développement Python sur la virtu...
# 6   Stage - PoC ordonnanceur AirFlow/Python dans l...
# 7                      Senior Python Backend Engineer
# 8                            Développeur Python (H/F)
# 9   Ingénieur Intégration Logiciel QA (Python, Lin...
# 10  STAGE - Ingénieur - Développement Logiciel de ...
# 11  Ingénieur(e) Développeur / Intégrateur (C++/Py...
# 12    Tech Lead Python dans le domaine des GNSS (H/F)
# 13         une Ingénieur(e) Validation (Python) (H/F)
# 14                     Ingénieur Développement Python
# 15  Développeur(euse) Python confirmé(e) / Consult...
# 16       Développeur(euse) Fullstack Python / Angular
# 17  Ingénieur Développement Python et C - PARIS (H/F)
# 18      Fullstack Software Engineer (Python, ReactJS)
# 19                   Staff Software Engineer (Python)
# 20                 Backend Software Engineer (Python)
# 21         Trading Systems - Développeur Python - H/F
# 22  Stage - Développeur Python pour Web Scraping A...
# 23                          Ingénieur Back-end Python
# 24                             Développeur Python H/F
# 25                             Développeur Python H/F
# 26                           Développeur Python (H/F)
# 27                   Stage - Développeur Python (H/F)
# 28        Lead Développeur Python - Rennes -  (f/m/x)
# 29  Développeur.se Python Expérimenté.e (f/d/m)- R...
# 30                                 Développeur Python
# 31   Développeur-Développeuse junior(e) Python/Django
#
#                        Job Location                       Company Name  \
# 0                             Paris                              Manty
# 1                            Nantes                            Artelys
# 2                             Paris                   The Product Crew
# 3                             Paris                   The Product Crew
# 4                             Paris                   The Product Crew
# 5                           Lannion                             Orange
# 6   Marseille - 3ème Arrondissement                             Orange
# 7                             Paris                              Yavin
# 8                             Paris                         Groupe SII
# 9                             Paris  Aldebaran - United Robotics Group
# 10                          Moirans                             Thales
# 11                           Nantes                             Thales
# 12                         Toulouse                             Thales
# 13                           Nantes                             Thales
# 14                         Bordeaux                             Thales
# 15                            Paris                           Innovela
# 16                            Paris                           Innovela
# 17                            Paris                          Capgemini
# 18                            Paris                        GitGuardian
# 19                            Paris                        GitGuardian
# 20                            Paris                        GitGuardian
# 21                            Paris                              MARGO
# 22                   33281 Merignac                             Enedis
# 23                         Bordeaux                           Adservio
# 24                            Paris                              EXTIA
# 25                      Montpellier                              EXTIA
# 26                            Paris                              EXTIA
# 27                         Toulouse                          Capgemini
# 28                           Rennes                       IDnow France
# 29                           Rennes                       IDnow France
# 30                        Vincennes                            Accenta
# 31                         Toulouse                      Makina Corpus
#
#    Job Type
# 0       CDI
# 1       CDI
# 2       CDI
# 3       CDI
# 4       CDI
# 5       CDI
# 6     Stage
# 7       CDI
# 8       CDI
# 9       CDI
# 10    Stage
# 11      CDI
# 12      CDI
# 13      CDI
# 14      CDI
# 15      CDI
# 16      CDI
# 17      CDI
# 18      CDI
# 19      CDI
# 20      CDI
# 21      CDI
# 22    Stage
# 23   Autres
# 24      CDI
# 25      CDI
# 26      CDI
# 27    Stage
# 28      CDI
# 29      CDI
# 30      CDI
# 31      CDI
